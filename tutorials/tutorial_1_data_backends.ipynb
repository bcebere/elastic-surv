# %% [markdown]
# # Tutorial 1: Data backends
#
# In this tutorial, we will review the data backends supported by the library.
#
# Supported scenarios include:
#  - Load data from Pandas
#  - Load data from an ES node.

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Load dataset
#
# For this demo, we will use the [User Churn dataset](https://square.github.io/pysurvival/tutorials/churn.html).

# %%
# !pip install pysurvival &> /dev/null
import numpy as np
from pysurvival.datasets import Dataset

# Load dataset
raw_dataset = Dataset('churn').load() 

time_column = 'months_active'
event_column = 'churned'

features = np.setdiff1d(raw_dataset.columns, [time_column, event_column] ).tolist()

raw_dataset
# Out:
#       product_data_storage product_travel_expense product_payroll  \
# 0                     2048             Free-Trial          Active
# 1                     2048             Free-Trial      Free-Trial
# 2                     2048                 Active          Active
# 3                      500                 Active      Free-Trial
# 4                     5120             Free-Trial          Active
# ...                    ...                    ...             ...
# 1995                  1024             Free-Trial          Active
# 1996                  1024             Free-Trial          Active
# 1997                   500             Free-Trial          Active
# 1998                   500             Free-Trial              No
# 1999                  1024             Free-Trial      Free-Trial
#
#      product_accounting  csat_score  articles_viewed  \
# 0                    No           9                4
# 1                Active           9                4
# 2                Active           9                3
# 3                    No          10                0
# 4            Free-Trial           8                5
# ...                 ...         ...              ...
# 1995         Free-Trial           9                3
# 1996             Active           7                3
# 1997             Active           8                5
# 1998             Active          10                6
# 1999         Free-Trial           8                5
#
#       smartphone_notifications_viewed  marketing_emails_clicked  \
# 0                                   0                        14
# 1                                   2                        12
# 2                                   2                        17
# 3                                   0                        14
# 4                                   0                        17
# ...                               ...                       ...
# 1995                                0                        19
# 1996                                0                        15
# 1997                                0                        15
# 1998                                1                        15
# 1999                                0                        18
#
#       social_media_ads_viewed  minutes_customer_support company_size  \
# 0                           1                       8.3        10-50
# 1                           1                       0.0      100-250
# 2                           1                       0.0      100-250
# 3                           0                       0.0       50-100
# 4                           0                       0.0       50-100
# ...                       ...                       ...          ...
# 1995                        1                       0.4       50-100
# 1996                        0                       0.0       50-100
# 1997                        0                       5.9        10-50
# 1998                        1                       3.3      100-250
# 1999                        0                       0.0       50-100
#
#                us_region  months_active  churned
# 0     West North Central            3.0      1.0
# 1         South Atlantic            2.0      1.0
# 2     East South Central            7.0      0.0
# 3     East South Central            8.0      1.0
# 4     East North Central            7.0      0.0
# ...                  ...            ...      ...
# 1995            Mountain            8.0      0.0
# 1996     Middle Atlantic            2.0      1.0
# 1997  West North Central            1.0      1.0
# 1998             Pacific            3.0      1.0
# 1999  East South Central            4.0      1.0
#
# [2000 rows x 14 columns]

# %% [markdown]
# ## Pandas backend for elastic-surv
#
# This variant is suitable for loading local data.
#
# The loading process also handle data encoding, as shown below.

# %%
from elastic_surv.dataset import PandasDataset

dataset = PandasDataset(
    raw_dataset,
    time_column=time_column,
    event_column=event_column,
    features=features,
    verbose = True,
)
# Out:
# preprocess: dataset one-hot encoding for company_size {'10-50', '50-100', '100-250', 'self-employed', '1-10'}
# preprocess: dataset one-hot encoding for product_accounting {'Active', 'No', 'Free-Trial'}
# preprocess: dataset one-hot encoding for product_payroll {'Active', 'No', 'Free-Trial'}
# preprocess: dataset one-hot encoding for product_travel_expense {'Active', 'No', 'Free-Trial'}
# preprocess: dataset one-hot encoding for us_region {'New England', 'West South Central', 'South Atlantic', 'West North Central', 'East North Central', 'Pacific', 'Middle Atlantic', 'Mountain', 'East South Central'}

# %%
len(dataset.train())
# Out:
# 1800

# %%
len(dataset.test())
# Out:
# 200

# %% [markdown]
# ## ElasticSearch backend

# %% [markdown]
# For this example, we will use a local ES server. Installation steps can be found [here](https://www.elastic.co/guide/en/elasticsearch/reference/current/install-elasticsearch.html).

# %% [markdown]
# ### Prepare the index for the demo
#
# We will create the index locally, for demo purposes.

# %%
import eland as ed

# Upload dataframe to ES
ed.pandas_to_eland(raw_dataset,
                   es_client='localhost',
                   es_dest_index='churn-prediction',
                   es_if_exists='replace',
                   es_dropna=True,
                   es_refresh=True,
                  )
# Out:
#       articles_viewed  churned company_size  csat_score  \
# 0                   4      1.0        10-50           9
# 1                   4      1.0      100-250           9
# 2                   3      0.0      100-250           9
# 3                   0      1.0       50-100          10
# 4                   5      0.0       50-100           8
# ...               ...      ...          ...         ...
# 1995                3      0.0       50-100           9
# 1996                3      1.0       50-100           7
# 1997                5      1.0        10-50           8
# 1998                6      1.0      100-250          10
# 1999                5      1.0       50-100           8
#
#       marketing_emails_clicked  minutes_customer_support  months_active  \
# 0                           14                       8.3            3.0
# 1                           12                       0.0            2.0
# 2                           17                       0.0            7.0
# 3                           14                       0.0            8.0
# 4                           17                       0.0            7.0
# ...                        ...                       ...            ...
# 1995                        19                       0.4            8.0
# 1996                        15                       0.0            2.0
# 1997                        15                       5.9            1.0
# 1998                        15                       3.3            3.0
# 1999                        18                       0.0            4.0
#
#      product_accounting  product_data_storage product_payroll  \
# 0                    No                  2048          Active
# 1                Active                  2048      Free-Trial
# 2                Active                  2048          Active
# 3                    No                   500      Free-Trial
# 4            Free-Trial                  5120          Active
# ...                 ...                   ...             ...
# 1995         Free-Trial                  1024          Active
# 1996             Active                  1024          Active
# 1997             Active                   500          Active
# 1998             Active                   500              No
# 1999         Free-Trial                  1024      Free-Trial
#
#      product_travel_expense  smartphone_notifications_viewed  \
# 0                Free-Trial                                0
# 1                Free-Trial                                2
# 2                    Active                                2
# 3                    Active                                0
# 4                Free-Trial                                0
# ...                     ...                              ...
# 1995             Free-Trial                                0
# 1996             Free-Trial                                0
# 1997             Free-Trial                                0
# 1998             Free-Trial                                1
# 1999             Free-Trial                                0
#
#       social_media_ads_viewed           us_region
# 0                           1  West North Central
# 1                           1      South Atlantic
# 2                           1  East South Central
# 3                           0  East South Central
# 4                           0  East North Central
# ...                       ...                 ...
# 1995                        1            Mountain
# 1996                        0     Middle Atlantic
# 1997                        0  West North Central
# 1998                        1             Pacific
# 1999                        0  East South Central
#
# [2000 rows x 14 columns]

# %% [markdown]
# We now have the `churn-prediction` index available in our local ES deploy.

# %% [markdown]
# ## ES backend for elastic-surv

# %%
from elastic_surv.dataset import ESDataset

dataset = ESDataset(
    es_index_pattern = 'churn-prediction',
    time_column = 'months_active',
    event_column = 'churned',
    verbose = True,
)
# Out:
# preprocess: dataset one-hot encoding for company_size {'10-50', '50-100', '100-250', 'self-employed', '1-10'}
# preprocess: dataset one-hot encoding for product_accounting {'Active', 'No', 'Free-Trial'}
# preprocess: dataset one-hot encoding for product_payroll {'Active', 'No', 'Free-Trial'}
# preprocess: dataset one-hot encoding for product_travel_expense {'Active', 'No', 'Free-Trial'}
# preprocess: dataset one-hot encoding for us_region {'New England', 'West South Central', 'South Atlantic', 'West North Central', 'East North Central', 'Pacific', 'Middle Atlantic', 'Mountain', 'East South Central'}

# %%
len(dataset.train())
# Out:
# 1800

# %%
len(dataset.test())
# Out:
# 200

# %% [markdown]
# ## Conclusion

# %% [markdown]
# In this tutorial, we've shown some basic examples for loading the data for `elastic-surv`.
# Next, we will train models on the loaded data.
